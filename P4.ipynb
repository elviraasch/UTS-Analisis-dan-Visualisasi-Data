# %% [markdown]
# <a href="https://colab.research.google.com/github/elviraasch/UTS-Analisis-dan-Visualisasi-Data/blob/main/P4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **P4**

# %%
import pandas as pd

wine_df = pd.read_csv('winequality-red.csv')

winered = ['alcohol', 'pH', 'residual sugar', 'citric acid']

for col in winered:
    median_val = df[col].median()
    df_grouped = df.groupby(df[col].apply(lambda x: 'high' if x >= median_val else 'low'))

    print(df_grouped['quality'].mean())
    print()
# Out:
# alcohol
# high    5.958904
# low     5.310302
# Name: quality, dtype: float64
#
# pH
# high    5.598039
# low     5.675607
# Name: quality, dtype: float64
#
# residual sugar
# high    5.665880
# low     5.602394
# Name: quality, dtype: float64
#
# citric acid
# high    5.822360
# low     5.447103
# Name: quality, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

print(wine_df.info())
print(wine_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(7, 4))
sns.countplot(data=wine_df, x='quality', palette='coolwarm')

plt.title('Distribusi Peringkat Kualitas Anggur (Quality Rating Score)', fontsize=12, pad=10)
plt.xlabel('Skor Kualitas')
plt.ylabel('Jumlah Sampel (Count)')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1033/3427458358.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=wine_df, x='quality', palette='coolwarm')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(9, 7))

matriks_korelasi = wine_df[['alcohol', 'pH', 'residual sugar', 'citric acid', 'quality']].corr()

sns.heatmap(matriks_korelasi, annot=True, cmap='RdBu_r', fmt='.3f', linewidths=0.5, vmin=-1, vmax=1)

plt.title('Matriks Korelasi Hubungan Sifat Fisikokimia dengan Kualitas Anggur')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(2, 2, figsize=(15, 11))

# Alcohol vs Quality
sns.boxplot(ax=axes[0, 0], data=wine_df, x='quality', y='alcohol', palette='Set2')

# pH vs Quality
sns.boxplot(ax=axes[0, 1], data=wine_df, x='quality', y='pH', palette='Set2')

# Residual Sugar vs Quality
sns.boxplot(ax=axes[1, 0], data=wine_df, x='quality', y='residual sugar', palette='Set2')

# Citric Acid vs Quality
sns.boxplot(ax=axes[1, 1], data=wine_df, x='quality', y='citric acid', palette='Set2')

plt.tight_layout(pad=3.0)
plt.show()
# Out:
# /tmp/ipykernel_1033/2215603292.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[0, 0], data=wine_df, x='quality', y='alcohol', palette='Set2')
# /tmp/ipykernel_1033/2215603292.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[0, 1], data=wine_df, x='quality', y='pH', palette='Set2')
# /tmp/ipykernel_1033/2215603292.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[1, 0], data=wine_df, x='quality', y='residual sugar', palette='Set2')
# /tmp/ipykernel_1033/2215603292.py:17: FutureWarning:
#
# ...
